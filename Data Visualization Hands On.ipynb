# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/lx5gnlyrog5hozt6sewsw2mqh4jq4s')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    Unnamed: 0  customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0           0  7590-VHVEG  Female            No     Yes         No       1
# 1           1  5575-GNVDE    Male            No      No         No      34
# 2           2  3668-QPYBK    Male            No      No         No       2
# 3           3  7795-CFOCW    Male            No      No         No      45
# 4           4  9237-HQITU  Female            No      No         No       2
#
#   PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0           No  No phone service             DSL  ...               No
# 1          Yes                No             DSL  ...              Yes
# 2          Yes                No             DSL  ...               No
# 3           No  No phone service             DSL  ...              Yes
# 4          Yes                No     Fiber optic  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
plt.hist(df.MonthlyCharges)
# Out:
# (array([1606.,  191.,  365.,  639.,  473.,  895.,  953.,  869.,  758.,
#          294.]),
#  array([ 18.25,  28.3 ,  38.35,  48.4 ,  58.45,  68.5 ,  78.55,  88.6 ,
#          98.65, 108.7 , 118.75]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df.MonthlyCharges, hist=False)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
Churn = df[df['Churn']=='Yes']

# %%
NoChurn = df[df['Churn']=='No']

# %%
sns.distplot(Churn.MonthlyCharges, hist=False)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.distplot(NoChurn.MonthlyCharges, hist=False)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.distplot(Churn.MonthlyCharges, hist=False, label = 'Churn')
sns.distplot(NoChurn.MonthlyCharges, hist=False, label = 'Non Churn')
plt.legend()

# %%
sns.boxplot(Churn.MonthlyCharges)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges'>

# %%
sns.boxplot(NoChurn.MonthlyCharges)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges'>

# %%
sns.boxplot(Churn.tenure)
# Out:
# <AxesSubplot:xlabel='tenure'>

# %%
sns.boxplot(NoChurn.tenure)
# Out:
# <AxesSubplot:xlabel='tenure'>

# %%
plt.figure(figsize = (20,5))#Pixels: width, height
plt.subplot(1,2,1)
plt.title("Churn Tenure")
sns.boxplot(Churn.tenure)

plt.subplot(1,2,2)
plt.title("Non-Churn Tenure")
sns.boxplot(NoChurn.tenure)
# Out:
# <AxesSubplot:title={'center':'Non-Churn Tenure'}, xlabel='tenure'>

# %%
sns.boxplot(x = df['Churn'], y = df['tenure'])
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %%
sns.countplot(df['Churn'])
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='count'>

# %%
plt.figure(figsize = (20,5))#Pixels: width, height
plt.subplot(1,2,1)
plt.title("Churn Contract")
sns.countplot(Churn['Contract'])
plt.subplot(1,2,2)
plt.title("No Churn Contract")
sns.countplot(NoChurn['Contract'])
# Out:
# <AxesSubplot:title={'center':'No Churn Contract'}, xlabel='Contract', ylabel='count'>

# %%
sns.countplot('Contract', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %%
sns.countplot('InternetService', hue='Churn', data=df)
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
sns.boxplot(x = df['TotalCharges'], y = df['InternetService'])
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='InternetService'>
